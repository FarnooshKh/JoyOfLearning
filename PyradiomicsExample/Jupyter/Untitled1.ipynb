# %%
from __future__ import print_function
import six
import os  # needed navigate the system to get the input data

import radiomics
import pandas as pd
from radiomics import featureextractor

# %%
extractor = featureextractor.RadiomicsFeaturesExtractor()
extractor.enableAllImageTypes()
extractor.enableAllFeatures()
#extractor.enableFeatureClassByName() 
print('Extraction parameters:\n\t', extractor.settings)
print('Enabled filters:\n\t', extractor._enabledImagetypes)
print('Enabled features:\n\t', extractor._enabledFeatures)
#print('Enabled features:\n\t', extractor._enabledFeatures)
# Out:
# Extraction parameters:
# 	 {'minimumROIDimensions': 1, 'minimumROISize': None, 'normalize': False, 'normalizeScale': 1, 'removeOutliers': None, 'resampledPixelSpacing': None, 'interpolator': 'sitkBSpline', 'preCrop': False, 'padDistance': 5, 'distances': [1], 'force2D': False, 'force2Ddimension': 0, 'resegmentRange': None, 'label': 1, 'additionalInfo': True}
# Enabled filters:
# 	 {'Original': {}, 'Exponential': {}, 'Gradient': {}, 'LBP2D': {}, 'LBP3D': {}, 'LoG': {}, 'Logarithm': {}, 'Square': {}, 'SquareRoot': {}, 'Wavelet': {}}
# Enabled features:
# 	 {'firstorder': [], 'glcm': [], 'gldm': [], 'glrlm': [], 'glszm': [], 'ngtdm': [], 'shape': []}

# %%
result2 = extractor.execute('/Users/farnoosh/Documents/Projects/Data/nifti/BA5556/1_no_series_description.nii', '/Users/farnoosh/Documents/Projects/Data/nifti/BA5556-MASS/1_no_series_description.nii',  label=7)
# Out:
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# /Users/farnoosh/Projects/PyradiomicsExample/myenv/lib/python3.6/site-packages/radiomics/ngtdm.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   contrast = (numpy.sum(p_i[:, None] * p_i[None, :] * (i[:, None] - i[None, :]) ** 2) / (Ngp * (Ngp - 1))) * \
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# Could not load required package "skimage", cannot implement filter LBP 2D
# Could not load required package "scipy" or "trimesh", cannot implement filter LBP 3D
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# ...

# %%
print('Result type:', type(result2))  # result is returned in a Python ordered dictionary)
print('')
print('Calculated features')
i = 0
for key, value in six.iteritems(result2):
    print('\t', key, ':', value)
    i = i+1
print(i)
# Out:
# Result type: <class 'collections.OrderedDict'>
#
# Calculated features
# 	 general_info_BoundingBox : (214, 303, 12, 70, 54, 7)
# 	 general_info_CenterOfMassIndex : (15.933690795352994, 323.1236818588025, 245.8182305630027)
# 	 general_info_CenterOfMass : (-103.40636832856833, -558.8205167940762, 472.35180947701815)
# 	 general_info_EnabledImageTypes : {'Original': {}}
# 	 general_info_GeneralSettings : {'minimumROIDimensions': 1, 'minimumROISize': None, 'normalize': False, 'normalizeScale': 1, 'removeOutliers': None, 'resampledPixelSpacing': None, 'interpolator': 'sitkBSpline', 'preCrop': False, 'padDistance': 5, 'distances': [1], 'force2D': False, 'force2Ddimension': 0, 'resegmentRange': None, 'label': 7, 'additionalInfo': True, 'binWidth': 20, 'sigma': [1, 2, 3], 'verbose': True, 'voxelBased': False}
# 	 general_info_ImageHash : 4234064ee5672703fe8caa97058470206b14b68b
# 	 general_info_ImageSpacing : (0.431640625, 0.4316408038139343, 3.000011920928955)
# ...

# %%
feature = pd.read_csv("/Users/farnoosh/Projects/DeepCINET/Data/CC/radiomic_features_name1.csv")

# %%
feature
# Out:
#                                              Unnamed: 0          CX10  \
# 0                               firstorder_10Percentile  2.070000e+02
# 1                               firstorder_90Percentile  4.090000e+02
# 2                                     firstorder_Energy  2.970406e+09
# 3                                    firstorder_Entropy  3.763291e+00
# 4                         firstorder_InterquartileRange  1.000000e+02
# 5                                   firstorder_Kurtosis  4.295891e+00
# 6                                    firstorder_Maximum  7.820000e+02
# 7                      firstorder_MeanAbsoluteDeviation  6.377689e+01
# 8                                       firstorder_Mean  3.055273e+02
# 9                                     firstorder_Median  3.010000e+02
# 10                                   firstorder_Minimum  0.000000e+00
# 11                                     firstorder_Range  7.820000e+02
# ...

# %%
i = 0
for key, value in six.iteritems(result2):
    try:
        print('\t', feature[feature['Unnamed: 0'] == key], ':', value)
        if(feature[feature['Unnamed: 0'] == key]):
            i = i+1  
    except:
        print("-")
print(i)
# Out:
# 	 Series([], Name: Unnamed: 0, dtype: object) : (214, 303, 12, 70, 54, 7)
# -
# 	 Series([], Name: Unnamed: 0, dtype: object) : (15.933690795352994, 323.1236818588025, 245.8182305630027)
# -
# 	 Series([], Name: Unnamed: 0, dtype: object) : (-103.40636832856833, -558.8205167940762, 472.35180947701815)
# -
# 	 Series([], Name: Unnamed: 0, dtype: object) : {'Original': {}, 'Exponential': {}, 'Gradient': {}, 'LBP2D': {}, 'LBP3D': {}, 'LoG': {}, 'Logarithm': {}, 'Square': {}, 'SquareRoot': {}, 'Wavelet': {}}
# -
# 	 Series([], Name: Unnamed: 0, dtype: object) : {'minimumROIDimensions': 1, 'minimumROISize': None, 'normalize': False, 'normalizeScale': 1, 'removeOutliers': None, 'resampledPixelSpacing': None, 'interpolator': 'sitkBSpline', 'preCrop': False, 'padDistance': 5, 'distances': [1], 'force2D': False, 'force2Ddimension': 0, 'resegmentRange': None, 'label': 7, 'additionalInfo': True, 'voxelBased': False}
# -
# ...

# %%
result2
# Out:
# OrderedDict([('general_info_BoundingBox', (214, 303, 12, 70, 54, 7)),
#              ('general_info_CenterOfMassIndex',
#               (15.933690795352994, 323.1236818588025, 245.8182305630027)),
#              ('general_info_CenterOfMass',
#               (-103.40636832856833, -558.8205167940762, 472.35180947701815)),
#              ('general_info_EnabledImageTypes',
#               {'Original': {},
#                'Exponential': {},
#                'Gradient': {},
#                'LBP2D': {},
#                'LBP3D': {},
#                'LoG': {},
#                'Logarithm': {},
#                'Square': {},
#                'SquareRoot': {},
#                'Wavelet': {}}),
#              ('general_info_GeneralSettings',
#               {'minimumROIDimensions': 1,
#                'minimumROISize': None,
#                'normalize': False,
#                'normalizeScale': 1,
#                'removeOutliers': None,
#                'resampledPixelSpacing': None,
# ...
